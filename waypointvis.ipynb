# %%
import matplotlib.pyplot as plt
import numpy as np

track_name = "2022_march_pro"
absolute_path = "."
waypoints = np.load("%s/%s.npy" % (absolute_path, track_name))

print("Number of waypoints = " + str(waypoints.shape[0]))
for i, point in enumerate(waypoints):
    waypoint = (point[0], point[1],point[2])
    plt.scatter(waypoint[0], waypoint[1])
    print("Waypoint " + str(i) + ": " + str(waypoint))

plt.show()
# Out:
# Number of waypoints = 256
# Waypoint 0: (0.6390160322189331, -0.38880518823862076, 0.6829295754432678)
# Waypoint 1: (0.9395764470100403, -0.4098225012421608, 0.9788393974304199)
# Waypoint 2: (1.2399659752845764, -0.43316077440977097, 1.282634973526001)
# Waypoint 3: (1.5402329564094543, -0.4580264762043953, 1.5851049423217773)
# Waypoint 4: (1.840418517589569, -0.48385327123105526, 1.886819005012512)
# Waypoint 5: (2.140537977218628, -0.5104456385597587, 2.1887528896331787)
# Waypoint 6: (2.4405404329299927, -0.538322668755427, 2.4914159774780273)
# Waypoint 7: (2.7403780221939087, -0.5679201725870371, 2.794100046157837)
# Waypoint 8: (3.0400640964508057, -0.5990134887397289, 3.0963470935821533)
# Waypoint 9: (3.3396019935607915, -0.6315032988786697, 3.398386001586914)
# Waypoint 10: (3.6389814615249634, -0.6654218658804893, 3.7006049156188965)
# Waypoint 11: (3.9381535053253174, -0.7011203318834305, 3.997227907180786)
# ...

# %%
text = (waypoints)

# %%
text
# Out:
# array([[ 0.63901603, -0.38880519,  0.68292958,  0.1427841 ,  0.59510249,
#         -0.92039448],
#        [ 0.93957645, -0.4098225 ,  0.9788394 ,  0.1221305 ,  0.9003135 ,
#         -0.9417755 ],
#        [ 1.23996598, -0.43316077,  1.28263497,  0.09852983,  1.19729698,
#         -0.96485138],
#        ...,
#        [ 0.04019242, -0.3226475 ,  0.1082165 ,  0.20639721, -0.02783166,
#         -0.8516922 ],
#        [ 0.3391334 , -0.36022181,  0.39770609,  0.1699525 ,  0.2805607 ,
#         -0.89039612],
#        [ 0.63901603, -0.38880519,  0.68292958,  0.1427841 ,  0.59510249,
#         -0.92039448]])

# %%
for t in text:
    print(t,',')
# Out:
# [ 7.7236681  -1.66326052  7.08352089 -1.62774706  8.36381531 -1.69877398] ,
# [ 7.72014034 -0.78929926  7.08004045 -0.7657268   8.36024022 -0.81287172] ,
# [7.71661258 0.08466199 7.07656002 0.09629345 8.35666513 0.07303053] ,
# [7.71308482 0.95862325 7.07307959 0.9583137  8.35309005 0.95893279] ,
# [7.70955706 1.8325845  7.06959915 1.82033396 8.34951496 1.84483504] ,
# [7.68401456 2.15091598 7.05024576 2.06129193 8.31778336 2.24054003] ,
# [7.62083936 2.4609859  7.00248003 2.29568291 8.23919868 2.62628889] ,
# [7.5213995  2.75961804 6.92734909 2.52129698 8.11544991 2.99793911] ,
# [7.3870585  3.04363358 6.82589388 2.73575807 7.94822311 3.35150909] ,
# [7.21918511 3.30985641 6.69939709 2.9363389  7.73897314 3.68337393] ,
# [7.01914263 3.55510902 6.54866123 3.12112403 7.48962402 3.98909402] ,
# [6.45179343 4.07516444 6.03146696 3.59253907 6.8721199  4.5577898 ] ,
# [5.74782801 4.66609955 5.34666586 4.16742802 6.14899015 5.16477108] ,
# ...

# %%
import seaborn as sns
sns.set_theme()

# %%
data = waypoints

# %%
x_val = [x[0] for x in data]
y_val = [x[1] for x in data]

print (x_val)
plt.plot(x_val,y_val)
plt.plot(x_val,y_val,'or')
plt.show()
# Out:
# [0.6390160322189331, 0.9395764470100403, 1.2399659752845764, 1.5402329564094543, 1.840418517589569, 2.140537977218628, 2.4405404329299927, 2.7403780221939087, 3.0400640964508057, 3.3396019935607915, 3.6389814615249634, 3.9381535053253174, 4.237836837768555, 4.538318157196045, 4.839356422424316, 5.140634059906006, 5.441750526428223, 5.740957021713257, 6.03105616569519, 6.303186893463135, 6.553018093109131, 6.78168511390686, 6.989370107650757, 7.172133445739746, 7.328665018081665, 7.466354608535767, 7.56868839263916, 7.619514226913452, 7.6138176918029785, 7.556023836135864, 7.467482089996338, 7.366438627243042, 7.243969440460205, 7.14652943611145, 7.136090040206909, 7.200650930404663, 7.219257593154907, 7.193048477172852, 7.127617597579956, 7.0291290283203125, 6.912374496459961, 6.768607139587402, 6.578888893127441, 6.346921920776367, 6.083498001098633, 5.801698923110962, 5.509170055389404, 5.212587356567383, 4.916518926620483, 4.620884418487549, 4.324982404708862, 4.025102019309998, 3
# ...

# %%
fig, ax = plt.subplots(1,1) # gets a handle for the AxesSubplot object
ax.plot(x_val, y_val, 'ro')
ax.plot(x_val, y_val, 'b-')
ax.set_yscale('log')
fig.show()

# %%
# sns.scatterplot(data, x_val, y_val, s=100, color=".2", marker="+")
